# %% [markdown]
# # 🚀 Codomax AI & ML Internship
#
# ## 📅 Day 1: Setup Check
#
# ### 📌 Project:
# Environment Setup Verification
#
# ---

# %%
print("   CODOMAX AI & ML INTERNSHIP - DAY 1")
# Out:
#    CODOMAX AI & ML INTERNSHIP - DAY 1

# %% [markdown]
# ## 👨‍💻 Student Details

# %%
name = "Bibek"
course = "AI & ML Internship"
day = 1

print(f"Name    : {name}")
print(f"Course  : {course}")
print(f"Day     : {day}")
# Out:
# Name    : Bibek
# Course  : AI & ML Internship
# Day     : 1

# %% [markdown]
# ## ⚙️ Setup Status

# %%
python_installed = True
vscode_installed = True
git_installed = True
github_connected = True

print("Python Installed   :", python_installed)
print("VS Code Installed  :", vscode_installed)
print("Git Installed      :", git_installed)
print("GitHub Connected   :", github_connected)
# Out:
# Python Installed   : True
# VS Code Installed  : True
# Git Installed      : True
# GitHub Connected   : True

# %%
print("\n🎯 Setup Completed Successfully!")
print("🚀 Ready to start Python programming.")
# Out:
# 🎯 Setup Completed Successfully!
# 🚀 Ready to start Python programming.
